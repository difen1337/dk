# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as sci
from statsmodels.regression.linear_model import OLS

pd.set_option('float_format', '{:6.3f}'.format)
sns.set(style='ticks')

import warnings
warnings.filterwarnings("ignore")

# %%
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,4

# %%
df = pd.read_csv('cape.csv',sep = ";")[['Date','P','E','CAPE']][13:].reset_index()

# %%
del df['index']

# %%
df['E/P'] = df['E']/df['P']

# %%
df_c = pd.read_csv('CAT.csv')[['Date','Adj Close']]

# %%
df_c['return'] = df_c['Adj Close'].diff(1)/df_c['Adj Close'].shift(1)

# %%
df_r = df_c[['Date','return']][2:].reset_index()
del df_r['index']

# %%
df_r.head()
# Out:
#          Date  return
# 0  1963-02-01  -0.085
# 1  1963-03-01   0.043
# 2  1963-04-01   0.021
# 3  1963-05-01   0.201
# 4  1963-06-01  -0.028

# %%
df.head()
# Out:
#       Date      P      E   CAPE    E/P
# 0  1963,01 65.060  3.683 19.259  0.057
# 1  1963,02 65.920  3.697 19.469  0.056
# 2  1963,03 65.670  3.710 19.288  0.056
# 3  1963,04 68.760  3.753 20.150  0.055
# 4  1963,05 70.140  3.797 20.508  0.054

# %%
df.tail()
# Out:
#         Date        P       E   CAPE    E/P
# 677  2019,06 2890.170 135.270 29.284  0.047
# 678  2019,07 2996.114 134.480 29.987  0.045
# 679  2019,08 2897.498 133.690 28.705  0.046
# 680  2019,09 2982.156 132.900 29.230  0.045
# 681   2019,1 2977.680 135.407 28.841  0.045

# %%
df_r = df_r.reset_index()[['Date','return']]

# %%
#1 first model
pd_est_model=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,646):
    model = OLS(df_r.iloc[0+i:36+i,1], sm.add_constant(df.iloc[0+i:36+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_r.iloc[36+i,1])**2
    pd_est_model=pd_est_model.append({'date':df_r.iloc[36+i,0],'error_sq':oos},ignore_index = True)
    print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 48.651
# No. Observations:                  36   AIC:                            -95.30
# Df Residuals:                      35   BIC:                            -93.72
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0305      0.010      2.919      0.004       0.010       0.051
# ==============================================================================
# Omnibus:                        1.038   Durbin-Watson:                   2.438
# Prob(Omnibus):                  0.595   Jarque-Bera (JB):                0.668
# Skew:                           0.333   Prob(JB):                        0.716
# Kurtosis:                       2.967   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 49.117
# No. Observations:                  36   AIC:                            -96.23
# Df Residuals:                      35   BIC:                            -94.65
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0309      0.010      3.003      0.003       0.011       0.051
# ==============================================================================
# Omnibus:                        1.335   Durbin-Watson:                   2.408
# Prob(Omnibus):                  0.513   Jarque-Bera (JB):                0.925
# Skew:                           0.392   Prob(JB):                        0.630
# Kurtosis:                       2.955   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 49.127
# No. Observations:                  36   AIC:                            -96.25
# Df Residuals:                      35   BIC:                            -94.67
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0304      0.010      2.947      0.003       0.010       0.051
# ==============================================================================
# Omnibus:                        1.524   Durbin-Watson:                   2.465
# Prob(Omnibus):                  0.467   Jarque-Bera (JB):                1.060
# Skew:                           0.420   Prob(JB):                        0.589
# Kurtosis:                       2.974   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 46.785
# No. Observations:                  36   AIC:                            -91.57
# Df Residuals:                      35   BIC:                            -89.99
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0267      0.011      2.432      0.015       0.005       0.048
# ==============================================================================
# Omnibus:                        0.565   Durbin-Watson:                   2.067
# Prob(Omnibus):                  0.754   Jarque-Bera (JB):                0.372
# Skew:                           0.244   Prob(JB):                        0.830
# Kurtosis:                       2.896   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 50.751
# No. Observations:                  36   AIC:                            -99.50
# Df Residuals:                      35   BIC:                            -97.92
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0222      0.010      2.252      0.024       0.003       0.041
# ==============================================================================
# Omnibus:                        0.818   Durbin-Watson:                   2.331
# Prob(Omnibus):                  0.664   Jarque-Bera (JB):                0.805
# Skew:                          -0.140   Prob(JB):                        0.669
# Kurtosis:                       2.323   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 50.735
# No. Observations:                  36   AIC:                            -99.47
# Df Residuals:                      35   BIC:                            -97.89
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0222      0.010      2.248      0.025       0.003       0.041
# ==============================================================================
# Omnibus:                        0.829   Durbin-Watson:                   2.354
# Prob(Omnibus):                  0.661   Jarque-Bera (JB):                0.811
# Skew:                          -0.140   Prob(JB):                        0.667
# Kurtosis:                       2.320   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 48.623
# No. Observations:                  36   AIC:                            -95.25
# Df Residuals:                      35   BIC:                            -93.66
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0191      0.010      1.825      0.068      -0.001       0.040
# ==============================================================================
# Omnibus:                        1.301   Durbin-Watson:                   2.126
# Prob(Omnibus):                  0.522   Jarque-Bera (JB):                1.076
# Skew:                          -0.203   Prob(JB):                        0.584
# Kurtosis:                       2.257   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 48.478
# No. Observations:                  36   AIC:                            -94.96
# Df Residuals:                      35   BIC:                            -93.37
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0173      0.010      1.647      0.100      -0.003       0.038
# ==============================================================================
# Omnibus:                        1.398   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.497   Jarque-Bera (JB):                1.038
# Skew:                          -0.125   Prob(JB):                        0.595
# Kurtosis:                       2.206   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 48.293
# No. Observations:                  36   AIC:                            -94.59
# Df Residuals:                      35   BIC:                            -93.00
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0169      0.011      1.605      0.108      -0.004       0.038
# ==============================================================================
# Omnibus:                        1.592   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.451   Jarque-Bera (JB):                1.103
# Skew:                          -0.121   Prob(JB):                        0.576
# Kurtosis:                       2.177   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 48.728
# No. Observations:                  36   AIC:                            -95.46
# Df Residuals:                      35   BIC:                            -93.87
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0154      0.010      1.483      0.138      -0.005       0.036
# ==============================================================================
# Omnibus:                        1.042   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.594   Jarque-Bera (JB):                0.871
# Skew:                          -0.077   Prob(JB):                        0.647
# Kurtosis:                       2.254   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 48.409
# No. Observations:                  36   AIC:                            -94.82
# Df Residuals:                      35   BIC:                            -93.23
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0167      0.011      1.592      0.111      -0.004       0.037
# ==============================================================================
# Omnibus:                        1.473   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.479   Jarque-Bera (JB):                1.062
# Skew:                          -0.121   Prob(JB):                        0.588
# Kurtosis:                       2.194   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 47.808
# No. Observations:                  36   AIC:                            -93.62
# Df Residuals:                      35   BIC:                            -92.03
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0147      0.011      1.376      0.169      -0.006       0.036
# ==============================================================================
# Omnibus:                        2.337   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.311   Jarque-Bera (JB):                1.288
# Skew:                          -0.058   Prob(JB):                        0.525
# Kurtosis:                       2.081   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 46.574
# No. Observations:                  36   AIC:                            -91.15
# Df Residuals:                      35   BIC:                            -89.56
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0161      0.011      1.460      0.144      -0.006       0.038
# ==============================================================================
# Omnibus:                        1.736   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.420   Jarque-Bera (JB):                1.106
# Skew:                           0.040   Prob(JB):                        0.575
# Kurtosis:                       2.145   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 45.526
# No. Observations:                  36   AIC:                            -89.05
# Df Residuals:                      35   BIC:                            -87.47
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0126      0.011      1.104      0.270      -0.010       0.035
# ==============================================================================
# Omnibus:                        2.640   Durbin-Watson:                   2.283
# Prob(Omnibus):                  0.267   Jarque-Bera (JB):                1.392
# Skew:                           0.097   Prob(JB):                        0.499
# Kurtosis:                       2.056   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 42.969
# No. Observations:                  36   AIC:                            -83.94
# Df Residuals:                      35   BIC:                            -82.35
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0148      0.012      1.210      0.226      -0.009       0.039
# ==============================================================================
# Omnibus:                        1.496   Durbin-Watson:                   2.319
# Prob(Omnibus):                  0.473   Jarque-Bera (JB):                1.172
# Skew:                           0.436   Prob(JB):                        0.557
# Kurtosis:                       2.856   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 42.218
# No. Observations:                  36   AIC:                            -82.44
# Df Residuals:                      35   BIC:                            -80.85
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0187      0.012      1.499      0.134      -0.006       0.043
# ==============================================================================
# Omnibus:                        0.834   Durbin-Watson:                   2.252
# Prob(Omnibus):                  0.659   Jarque-Bera (JB):                0.838
# Skew:                           0.326   Prob(JB):                        0.658
# Kurtosis:                       2.635   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:18   Log-Likelihood:                 41.555
# No. Observations:                  36   AIC:                            -81.11
# Df Residuals:                      35   BIC:                            -79.53
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0156      0.013      1.231      0.218      -0.009       0.041
# ==============================================================================
# Omnibus:                        1.188   Durbin-Watson:                   2.338
# Prob(Omnibus):                  0.552   Jarque-Bera (JB):                1.169
# Skew:                           0.382   Prob(JB):                        0.557
# Kurtosis:                       2.556   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.654
# No. Observations:                  36   AIC:                            -81.31
# Df Residuals:                      35   BIC:                            -79.72
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0135      0.013      1.065      0.287      -0.011       0.038
# ==============================================================================
# Omnibus:                        1.611   Durbin-Watson:                   2.365
# Prob(Omnibus):                  0.447   Jarque-Bera (JB):                1.484
# Skew:                           0.462   Prob(JB):                        0.476
# Kurtosis:                       2.629   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.554
# No. Observations:                  36   AIC:                            -81.11
# Df Residuals:                      35   BIC:                            -79.52
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0139      0.013      1.091      0.275      -0.011       0.039
# ==============================================================================
# Omnibus:                        1.548   Durbin-Watson:                   2.362
# Prob(Omnibus):                  0.461   Jarque-Bera (JB):                1.451
# Skew:                           0.448   Prob(JB):                        0.484
# Kurtosis:                       2.595   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.584
# No. Observations:                  36   AIC:                            -81.17
# Df Residuals:                      35   BIC:                            -79.58
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0141      0.013      1.106      0.269      -0.011       0.039
# ==============================================================================
# Omnibus:                        1.512   Durbin-Watson:                   2.370
# Prob(Omnibus):                  0.470   Jarque-Bera (JB):                1.419
# Skew:                           0.443   Prob(JB):                        0.492
# Kurtosis:                       2.599   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.708
# No. Observations:                  36   AIC:                            -81.42
# Df Residuals:                      35   BIC:                            -79.83
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0131      0.013      1.037      0.300      -0.012       0.038
# ==============================================================================
# Omnibus:                        1.725   Durbin-Watson:                   2.389
# Prob(Omnibus):                  0.422   Jarque-Bera (JB):                1.563
# Skew:                           0.481   Prob(JB):                        0.458
# Kurtosis:                       2.656   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.556
# No. Observations:                  36   AIC:                            -81.11
# Df Residuals:                      35   BIC:                            -79.53
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0098      0.013      0.774      0.439      -0.015       0.035
# ==============================================================================
# Omnibus:                        2.408   Durbin-Watson:                   2.381
# Prob(Omnibus):                  0.300   Jarque-Bera (JB):                2.116
# Skew:                           0.576   Prob(JB):                        0.347
# Kurtosis:                       2.712   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 42.266
# No. Observations:                  36   AIC:                            -82.53
# Df Residuals:                      35   BIC:                            -80.95
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0049      0.012      0.396      0.692      -0.019       0.029
# ==============================================================================
# Omnibus:                        3.656   Durbin-Watson:                   2.384
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                2.959
# Skew:                           0.702   Prob(JB):                        0.228
# Kurtosis:                       2.988   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 42.250
# No. Observations:                  36   AIC:                            -82.50
# Df Residuals:                      35   BIC:                            -80.92
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0063      0.012      0.508      0.611      -0.018       0.031
# ==============================================================================
# Omnibus:                        3.117   Durbin-Watson:                   2.423
# Prob(Omnibus):                  0.210   Jarque-Bera (JB):                2.520
# Skew:                           0.647   Prob(JB):                        0.284
# Kurtosis:                       2.932   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.549
# No. Observations:                  36   AIC:                            -81.10
# Df Residuals:                      35   BIC:                            -79.51
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0044      0.013      0.343      0.732      -0.021       0.029
# ==============================================================================
# Omnibus:                        2.958   Durbin-Watson:                   2.339
# Prob(Omnibus):                  0.228   Jarque-Bera (JB):                2.490
# Skew:                           0.639   Prob(JB):                        0.288
# Kurtosis:                       2.835   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.912
# No. Observations:                  36   AIC:                            -81.82
# Df Residuals:                      35   BIC:                            -80.24
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.013     -0.011      0.991      -0.025       0.025
# ==============================================================================
# Omnibus:                        4.350   Durbin-Watson:                   2.240
# Prob(Omnibus):                  0.114   Jarque-Bera (JB):                3.524
# Skew:                           0.765   Prob(JB):                        0.172
# Kurtosis:                       3.074   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 42.477
# No. Observations:                  36   AIC:                            -82.95
# Df Residuals:                      35   BIC:                            -81.37
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.012      0.189      0.850      -0.022       0.027
# ==============================================================================
# Omnibus:                        4.179   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.273
# Skew:                           0.736   Prob(JB):                        0.195
# Kurtosis:                       3.133   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:19   Log-Likelihood:                 41.961
# No. Observations:                  36   AIC:                            -81.92
# Df Residuals:                      35   BIC:                            -80.34
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0030      0.013      0.235      0.814      -0.022       0.028
# ==============================================================================
# Omnibus:                        4.303   Durbin-Watson:                   2.055
# ...
# Omnibus:                        5.848   Durbin-Watson:                   2.692
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                4.351
# Skew:                          -0.757   Prob(JB):                        0.114
# Kurtosis:                       3.781   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 43.151
# No. Observations:                  36   AIC:                            -84.30
# Df Residuals:                      35   BIC:                            -82.72
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0250      0.012      2.056      0.040       0.001       0.049
# ==============================================================================
# Omnibus:                        6.345   Durbin-Watson:                   2.802
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                4.841
# Skew:                          -0.765   Prob(JB):                       0.0889
# Kurtosis:                       3.942   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 44.139
# No. Observations:                  36   AIC:                            -86.28
# Df Residuals:                      35   BIC:                            -84.69
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0210      0.012      1.775      0.076      -0.002       0.044
# ==============================================================================
# Omnibus:                        6.631   Durbin-Watson:                   2.902
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                5.176
# Skew:                          -0.757   Prob(JB):                       0.0752
# Kurtosis:                       4.077   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 44.136
# No. Observations:                  36   AIC:                            -86.27
# Df Residuals:                      35   BIC:                            -84.69
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0214      0.012      1.807      0.071      -0.002       0.045
# ==============================================================================
# Omnibus:                        6.815   Durbin-Watson:                   2.882
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                5.369
# Skew:                          -0.773   Prob(JB):                       0.0682
# Kurtosis:                       4.092   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 42.422
# No. Observations:                  36   AIC:                            -82.84
# Df Residuals:                      35   BIC:                            -81.26
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0192      0.012      1.550      0.121      -0.005       0.044
# ==============================================================================
# Omnibus:                        6.365   Durbin-Watson:                   2.702
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                4.872
# Skew:                          -0.809   Prob(JB):                       0.0875
# Kurtosis:                       3.794   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 41.281
# No. Observations:                  36   AIC:                            -80.56
# Df Residuals:                      35   BIC:                            -78.98
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0218      0.013      1.701      0.089      -0.003       0.047
# ==============================================================================
# Omnibus:                        5.167   Durbin-Watson:                   2.876
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                3.762
# Skew:                          -0.735   Prob(JB):                        0.152
# Kurtosis:                       3.589   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 41.469
# No. Observations:                  36   AIC:                            -80.94
# Df Residuals:                      35   BIC:                            -79.36
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0183      0.013      1.436      0.151      -0.007       0.043
# ==============================================================================
# Omnibus:                        4.204   Durbin-Watson:                   3.006
# Prob(Omnibus):                  0.122   Jarque-Bera (JB):                2.883
# Skew:                          -0.642   Prob(JB):                        0.237
# Kurtosis:                       3.524   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 40.552
# No. Observations:                  36   AIC:                            -79.10
# Df Residuals:                      35   BIC:                            -77.52
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0158      0.013      1.211      0.226      -0.010       0.041
# ==============================================================================
# Omnibus:                        2.938   Durbin-Watson:                   2.839
# Prob(Omnibus):                  0.230   Jarque-Bera (JB):                2.019
# Skew:                          -0.571   Prob(JB):                        0.364
# Kurtosis:                       3.203   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 40.754
# No. Observations:                  36   AIC:                            -79.51
# Df Residuals:                      35   BIC:                            -77.93
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0152      0.013      1.171      0.242      -0.010       0.041
# ==============================================================================
# Omnibus:                        3.012   Durbin-Watson:                   2.881
# Prob(Omnibus):                  0.222   Jarque-Bera (JB):                2.039
# Skew:                          -0.570   Prob(JB):                        0.361
# Kurtosis:                       3.245   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):                nan
# Time:                        21:28:27   Log-Likelihood:                 40.798
# No. Observations:                  36   AIC:                            -79.60
# Df Residuals:                      35   BIC:                            -78.01
# Df Model:                           0
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0194      0.013      1.495      0.135      -0.006       0.045
# ==============================================================================
# Omnibus:                        4.243   Durbin-Watson:                   2.681
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                3.029
# Skew:                          -0.683   Prob(JB):                        0.220
# Kurtosis:                       3.391   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)

# %%
# second model
pd_est_model2=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,646):
    model = OLS(df_r.iloc[0+i:36+i,1], sm.add_constant(df.iloc[0+i:36+i,4]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df.iloc[36+i,4] - df_r.iloc[36+i,1])**2
    pd_est_model2=pd_est_model2.append({'date':df_r.iloc[36+i,0],'error_sq':oos},ignore_index = True)
    print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.7077
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.406
# Time:                        21:28:32   Log-Likelihood:                 48.950
# No. Observations:                  36   AIC:                            -93.90
# Df Residuals:                      34   BIC:                            -90.73
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3506      0.382      0.919      0.358      -0.397       1.098
# E/P           -5.8656      6.972     -0.841      0.400     -19.531       7.800
# ==============================================================================
# Omnibus:                        0.873   Durbin-Watson:                   2.481
# Prob(Omnibus):                  0.646   Jarque-Bera (JB):                0.606
# Skew:                           0.314   Prob(JB):                        0.739
# Kurtosis:                       2.905   Cond. No.                         733.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                    0.5154
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.478
# Time:                        21:28:32   Log-Likelihood:                 49.316
# No. Observations:                  36   AIC:                            -94.63
# Df Residuals:                      34   BIC:                            -91.46
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2926      0.366      0.799      0.424      -0.425       1.010
# E/P           -4.7961      6.680     -0.718      0.473     -17.889       8.297
# ==============================================================================
# Omnibus:                        1.128   Durbin-Watson:                   2.442
# Prob(Omnibus):                  0.569   Jarque-Bera (JB):                0.789
# Skew:                           0.361   Prob(JB):                        0.674
# Kurtosis:                       2.925   Cond. No.                         742.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.6506
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.426
# Time:                        21:28:32   Log-Likelihood:                 49.365
# No. Observations:                  36   AIC:                            -94.73
# Df Residuals:                      34   BIC:                            -91.56
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3087      0.347      0.890      0.374      -0.371       0.989
# E/P           -5.0983      6.321     -0.807      0.420     -17.487       7.290
# ==============================================================================
# Omnibus:                        1.262   Durbin-Watson:                   2.512
# Prob(Omnibus):                  0.532   Jarque-Bera (JB):                0.872
# Skew:                           0.380   Prob(JB):                        0.647
# Kurtosis:                       2.949   Cond. No.                         721.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     3.042
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):             0.0902
# Time:                        21:28:32   Log-Likelihood:                 48.279
# No. Observations:                  36   AIC:                            -92.56
# Df Residuals:                      34   BIC:                            -89.39
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6507      0.358      1.816      0.069      -0.051       1.353
# E/P          -11.4084      6.541     -1.744      0.081     -24.229       1.412
# ==============================================================================
# Omnibus:                        0.990   Durbin-Watson:                   2.291
# Prob(Omnibus):                  0.610   Jarque-Bera (JB):                0.860
# Skew:                           0.358   Prob(JB):                        0.650
# Kurtosis:                       2.756   Cond. No.                         615.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     2.222
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.145
# Time:                        21:28:32   Log-Likelihood:                 52.125
# No. Observations:                  36   AIC:                            -100.2
# Df Residuals:                      34   BIC:                            -97.08
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5204      0.334      1.557      0.120      -0.135       1.176
# E/P           -9.0912      6.098     -1.491      0.136     -21.044       2.861
# ==============================================================================
# Omnibus:                        6.131   Durbin-Watson:                   2.506
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                2.058
# Skew:                          -0.087   Prob(JB):                        0.357
# Kurtosis:                       1.842   Cond. No.                         569.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     4.271
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):             0.0465
# Time:                        21:28:32   Log-Likelihood:                 52.604
# No. Observations:                  36   AIC:                            -101.2
# Df Residuals:                      34   BIC:                            -98.04
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4952      0.230      2.154      0.031       0.045       0.946
# E/P           -8.5951      4.159     -2.067      0.039     -16.747      -0.443
# ==============================================================================
# Omnibus:                        4.321   Durbin-Watson:                   2.570
# Prob(Omnibus):                  0.115   Jarque-Bera (JB):                1.845
# Skew:                          -0.168   Prob(JB):                        0.397
# Kurtosis:                       1.943   Cond. No.                         464.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.162
# Method:                 Least Squares   F-statistic:                     10.18
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):            0.00305
# Time:                        21:28:32   Log-Likelihood:                 52.324
# No. Observations:                  36   AIC:                            -100.6
# Df Residuals:                      34   BIC:                            -97.48
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6020      0.184      3.267      0.001       0.241       0.963
# E/P          -10.5456      3.306     -3.190      0.001     -17.025      -4.066
# ==============================================================================
# Omnibus:                        5.826   Durbin-Watson:                   2.546
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                2.100
# Skew:                          -0.162   Prob(JB):                        0.350
# Kurtosis:                       1.862   Cond. No.                         391.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     10.56
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):            0.00260
# Time:                        21:28:32   Log-Likelihood:                 52.199
# No. Observations:                  36   AIC:                            -100.4
# Df Residuals:                      34   BIC:                            -97.23
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5344      0.161      3.325      0.001       0.219       0.849
# E/P           -9.3197      2.868     -3.250      0.001     -14.940      -3.699
# ==============================================================================
# Omnibus:                        5.983   Durbin-Watson:                   2.529
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                2.104
# Skew:                          -0.148   Prob(JB):                        0.349
# Kurtosis:                       1.853   Cond. No.                         344.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     13.50
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):           0.000816
# Time:                        21:28:32   Log-Likelihood:                 52.442
# No. Observations:                  36   AIC:                            -100.9
# Df Residuals:                      34   BIC:                            -97.72
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4648      0.124      3.749      0.000       0.222       0.708
# E/P           -8.0187      2.183     -3.674      0.000     -12.297      -3.741
# ==============================================================================
# Omnibus:                        4.333   Durbin-Watson:                   2.474
# Prob(Omnibus):                  0.115   Jarque-Bera (JB):                1.953
# Skew:                          -0.227   Prob(JB):                        0.377
# Kurtosis:                       1.953   Cond. No.                         280.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     4.910
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):             0.0335
# Time:                        21:28:32   Log-Likelihood:                 51.234
# No. Observations:                  36   AIC:                            -98.47
# Df Residuals:                      34   BIC:                            -95.30
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3083      0.133      2.327      0.020       0.049       0.568
# E/P           -5.2013      2.347     -2.216      0.027      -9.802      -0.601
# ==============================================================================
# Omnibus:                        3.188   Durbin-Watson:                   2.359
# Prob(Omnibus):                  0.203   Jarque-Bera (JB):                1.545
# Skew:                          -0.119   Prob(JB):                        0.462
# Kurtosis:                       2.013   Cond. No.                         232.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     1.887
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.179
# Time:                        21:28:32   Log-Likelihood:                 49.496
# No. Observations:                  36   AIC:                            -94.99
# Df Residuals:                      34   BIC:                            -91.83
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1903      0.126      1.511      0.131      -0.057       0.437
# E/P           -3.0566      2.225     -1.374      0.170      -7.418       1.305
# ==============================================================================
# Omnibus:                        3.102   Durbin-Watson:                   2.164
# Prob(Omnibus):                  0.212   Jarque-Bera (JB):                1.517
# Skew:                          -0.111   Prob(JB):                        0.468
# Kurtosis:                       2.019   Cond. No.                         201.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     2.841
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.101
# Time:                        21:28:32   Log-Likelihood:                 49.356
# No. Observations:                  36   AIC:                            -94.71
# Df Residuals:                      34   BIC:                            -91.55
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2119      0.117      1.812      0.070      -0.017       0.441
# E/P           -3.4505      2.047     -1.686      0.092      -7.462       0.562
# ==============================================================================
# Omnibus:                        3.511   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.173   Jarque-Bera (JB):                1.576
# Skew:                          -0.068   Prob(JB):                        0.455
# Kurtosis:                       1.984   Cond. No.                         188.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.6125
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.439
# Time:                        21:28:32   Log-Likelihood:                 46.943
# No. Observations:                  36   AIC:                            -89.89
# Df Residuals:                      34   BIC:                            -86.72
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1131      0.122      0.925      0.355      -0.126       0.353
# E/P           -1.6843      2.152     -0.783      0.434      -5.902       2.534
# ==============================================================================
# Omnibus:                        1.162   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.559   Jarque-Bera (JB):                0.943
# Skew:                           0.119   Prob(JB):                        0.624
# Kurtosis:                       2.244   Cond. No.                         179.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                    0.9826
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.329
# Time:                        21:28:32   Log-Likelihood:                 46.135
# No. Observations:                  36   AIC:                            -88.27
# Df Residuals:                      34   BIC:                            -85.10
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1389      0.126      1.105      0.269      -0.107       0.385
# E/P           -2.1835      2.203     -0.991      0.322      -6.501       2.134
# ==============================================================================
# Omnibus:                        1.626   Durbin-Watson:                   2.380
# Prob(Omnibus):                  0.444   Jarque-Bera (JB):                1.206
# Skew:                           0.206   Prob(JB):                        0.547
# Kurtosis:                       2.204   Cond. No.                         176.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.024
# Method:                 Least Squares   F-statistic:                    0.1675
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.685
# Time:                        21:28:32   Log-Likelihood:                 43.056
# No. Observations:                  36   AIC:                            -82.11
# Df Residuals:                      34   BIC:                            -78.94
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0666      0.123      0.542      0.588      -0.174       0.307
# E/P           -0.8907      2.176     -0.409      0.682      -5.157       3.375
# ==============================================================================
# Omnibus:                        2.143   Durbin-Watson:                   2.328
# Prob(Omnibus):                  0.342   Jarque-Bera (JB):                1.561
# Skew:                           0.510   Prob(JB):                        0.458
# Kurtosis:                       2.996   Cond. No.                         176.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                    0.1561
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.695
# Time:                        21:28:32   Log-Likelihood:                 42.294
# No. Observations:                  36   AIC:                            -80.59
# Df Residuals:                      34   BIC:                            -77.42
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0688      0.123      0.559      0.576      -0.172       0.310
# E/P           -0.8578      2.171     -0.395      0.693      -5.113       3.397
# ==============================================================================
# Omnibus:                        1.170   Durbin-Watson:                   2.261
# Prob(Omnibus):                  0.557   Jarque-Bera (JB):                1.018
# Skew:                           0.392   Prob(JB):                        0.601
# Kurtosis:                       2.746   Cond. No.                         177.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                    0.1506
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.700
# Time:                        21:28:32   Log-Likelihood:                 41.627
# No. Observations:                  36   AIC:                            -79.25
# Df Residuals:                      34   BIC:                            -76.09
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0660      0.126      0.522      0.602      -0.182       0.314
# E/P           -0.8599      2.216     -0.388      0.698      -5.203       3.484
# ==============================================================================
# Omnibus:                        1.455   Durbin-Watson:                   2.349
# Prob(Omnibus):                  0.483   Jarque-Bera (JB):                1.329
# Skew:                           0.439   Prob(JB):                        0.515
# Kurtosis:                       2.662   Cond. No.                         180.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                   0.07884
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.781
# Time:                        21:28:32   Log-Likelihood:                 41.692
# No. Observations:                  36   AIC:                            -79.38
# Df Residuals:                      34   BIC:                            -76.22
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0506      0.129      0.392      0.695      -0.202       0.303
# E/P           -0.6316      2.249     -0.281      0.779      -5.040       3.777
# ==============================================================================
# Omnibus:                        1.858   Durbin-Watson:                   2.371
# Prob(Omnibus):                  0.395   Jarque-Bera (JB):                1.639
# Skew:                           0.501   Prob(JB):                        0.441
# Kurtosis:                       2.703   Cond. No.                         182.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                   0.04808
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.828
# Time:                        21:28:32   Log-Likelihood:                 41.576
# No. Observations:                  36   AIC:                            -79.15
# Df Residuals:                      34   BIC:                            -75.99
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0431      0.131      0.330      0.741      -0.213       0.299
# E/P           -0.4975      2.269     -0.219      0.826      -4.945       3.950
# ==============================================================================
# Omnibus:                        1.704   Durbin-Watson:                   2.365
# Prob(Omnibus):                  0.427   Jarque-Bera (JB):                1.552
# Skew:                           0.477   Prob(JB):                        0.460
# Kurtosis:                       2.646   Cond. No.                         184.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                   0.07989
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.779
# Time:                        21:28:32   Log-Likelihood:                 41.622
# No. Observations:                  36   AIC:                            -79.24
# Df Residuals:                      34   BIC:                            -76.08
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0529      0.135      0.393      0.695      -0.211       0.317
# E/P           -0.6591      2.332     -0.283      0.777      -5.230       3.912
# ==============================================================================
# Omnibus:                        1.710   Durbin-Watson:                   2.376
# Prob(Omnibus):                  0.425   Jarque-Bera (JB):                1.540
# Skew:                           0.479   Prob(JB):                        0.463
# Kurtosis:                       2.670   Cond. No.                         187.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                   0.04431
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.835
# Time:                        21:28:32   Log-Likelihood:                 41.729
# No. Observations:                  36   AIC:                            -79.46
# Df Residuals:                      34   BIC:                            -76.29
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0424      0.136      0.311      0.756      -0.225       0.310
# E/P           -0.4958      2.355     -0.210      0.833      -5.112       4.121
# ==============================================================================
# Omnibus:                        1.897   Durbin-Watson:                   2.393
# Prob(Omnibus):                  0.387   Jarque-Bera (JB):                1.670
# Skew:                           0.507   Prob(JB):                        0.434
# Kurtosis:                       2.706   Cond. No.                         189.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                 0.0001018
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.992
# Time:                        21:28:32   Log-Likelihood:                 41.556
# No. Observations:                  36   AIC:                            -79.11
# Df Residuals:                      34   BIC:                            -75.94
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0084      0.138      0.061      0.951      -0.262       0.279
# E/P            0.0240      2.377      0.010      0.992      -4.634       4.682
# ==============================================================================
# Omnibus:                        2.399   Durbin-Watson:                   2.381
# Prob(Omnibus):                  0.301   Jarque-Bera (JB):                2.110
# Skew:                           0.575   Prob(JB):                        0.348
# Kurtosis:                       2.710   Cond. No.                         190.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                    0.1703
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.682
# Time:                        21:28:32   Log-Likelihood:                 42.346
# No. Observations:                  36   AIC:                            -80.69
# Df Residuals:                      34   BIC:                            -77.52
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0515      0.134     -0.385      0.700      -0.314       0.211
# E/P            0.9548      2.314      0.413      0.680      -3.580       5.490
# ==============================================================================
# Omnibus:                        3.120   Durbin-Watson:                   2.394
# Prob(Omnibus):                  0.210   Jarque-Bera (JB):                2.554
# Skew:                           0.651   Prob(JB):                        0.279
# Kurtosis:                       2.907   Cond. No.                         193.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.026
# Method:                 Least Squares   F-statistic:                    0.1082
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.744
# Time:                        21:28:32   Log-Likelihood:                 42.302
# No. Observations:                  36   AIC:                            -80.60
# Df Residuals:                      34   BIC:                            -77.44
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0402      0.139     -0.290      0.772      -0.312       0.231
# E/P            0.7850      2.386      0.329      0.742      -3.891       5.461
# ==============================================================================
# Omnibus:                        2.727   Durbin-Watson:                   2.428
# Prob(Omnibus):                  0.256   Jarque-Bera (JB):                2.244
# Skew:                           0.608   Prob(JB):                        0.326
# Kurtosis:                       2.864   Cond. No.                         196.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                    0.1738
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.679
# Time:                        21:28:32   Log-Likelihood:                 41.631
# No. Observations:                  36   AIC:                            -79.26
# Df Residuals:                      34   BIC:                            -76.09
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0558      0.142     -0.393      0.694      -0.334       0.223
# E/P            1.0149      2.435      0.417      0.677      -3.757       5.787
# ==============================================================================
# Omnibus:                        2.588   Durbin-Watson:                   2.345
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                2.240
# Skew:                           0.598   Prob(JB):                        0.326
# Kurtosis:                       2.753   Cond. No.                         198.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.6221
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.436
# Time:                        21:28:32   Log-Likelihood:                 42.195
# No. Observations:                  36   AIC:                            -80.39
# Df Residuals:                      34   BIC:                            -77.22
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1122      0.139     -0.805      0.421      -0.385       0.161
# E/P            1.8882      2.394      0.789      0.430      -2.804       6.580
# ==============================================================================
# Omnibus:                        3.453   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.178   Jarque-Bera (JB):                2.825
# Skew:                           0.686   Prob(JB):                        0.244
# Kurtosis:                       2.941   Cond. No.                         201.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.3359
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.566
# Time:                        21:28:32   Log-Likelihood:                 42.633
# No. Observations:                  36   AIC:                            -81.27
# Df Residuals:                      34   BIC:                            -78.10
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...
# Method:                 Least Squares   F-statistic:                   0.02690
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.871
# Time:                        21:28:42   Log-Likelihood:                 43.159
# No. Observations:                  36   AIC:                            -82.32
# Df Residuals:                      34   BIC:                            -79.15
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0018      0.161     -0.011      0.991      -0.317       0.314
# E/P            0.6169      3.761      0.164      0.870      -6.755       7.989
# ==============================================================================
# Omnibus:                        6.587   Durbin-Watson:                   2.794
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                5.097
# Skew:                          -0.777   Prob(JB):                       0.0782
# Kurtosis:                       3.991   Cond. No.                         394.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                   0.07621
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.784
# Time:                        21:28:42   Log-Likelihood:                 44.163
# No. Observations:                  36   AIC:                            -84.33
# Df Residuals:                      34   BIC:                            -81.16
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0632      0.151      0.417      0.676      -0.233       0.360
# E/P           -0.9682      3.507     -0.276      0.782      -7.842       5.906
# ==============================================================================
# Omnibus:                        6.355   Durbin-Watson:                   2.920
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                4.871
# Skew:                          -0.745   Prob(JB):                       0.0875
# Kurtosis:                       4.013   Cond. No.                         377.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                   0.06094
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.807
# Time:                        21:28:42   Log-Likelihood:                 44.154
# No. Observations:                  36   AIC:                            -84.31
# Df Residuals:                      34   BIC:                            -81.14
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0563      0.141      0.400      0.689      -0.220       0.332
# E/P           -0.7989      3.236     -0.247      0.805      -7.142       5.544
# ==============================================================================
# Omnibus:                        6.637   Durbin-Watson:                   2.895
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                5.165
# Skew:                          -0.768   Prob(JB):                       0.0756
# Kurtosis:                       4.043   Cond. No.                         365.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                    0.6095
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.440
# Time:                        21:28:42   Log-Likelihood:                 42.626
# No. Observations:                  36   AIC:                            -81.25
# Df Residuals:                      34   BIC:                            -78.08
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1445      0.158      0.912      0.362      -0.166       0.455
# E/P           -2.8599      3.663     -0.781      0.435     -10.040       4.320
# ==============================================================================
# Omnibus:                        5.644   Durbin-Watson:                   2.776
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                4.203
# Skew:                          -0.773   Prob(JB):                        0.122
# Kurtosis:                       3.644   Cond. No.                         363.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                    0.1112
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.741
# Time:                        21:28:42   Log-Likelihood:                 41.315
# No. Observations:                  36   AIC:                            -78.63
# Df Residuals:                      34   BIC:                            -75.46
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0749      0.157      0.478      0.633      -0.232       0.382
# E/P           -1.2072      3.620     -0.334      0.739      -8.302       5.887
# ==============================================================================
# Omnibus:                        4.846   Durbin-Watson:                   2.901
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                3.487
# Skew:                          -0.714   Prob(JB):                        0.175
# Kurtosis:                       3.533   Cond. No.                         358.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                    0.1029
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.750
# Time:                        21:28:42   Log-Likelihood:                 41.501
# No. Observations:                  36   AIC:                            -79.00
# Df Residuals:                      34   BIC:                            -75.84
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0685      0.155      0.444      0.657      -0.234       0.371
# E/P           -1.1388      3.550     -0.321      0.748      -8.098       5.820
# ==============================================================================
# Omnibus:                        3.954   Durbin-Watson:                   3.030
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                2.681
# Skew:                          -0.624   Prob(JB):                        0.262
# Kurtosis:                       3.480   Cond. No.                         356.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.026
# Method:                 Least Squares   F-statistic:                    0.2024
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.656
# Time:                        21:28:42   Log-Likelihood:                 40.615
# No. Observations:                  36   AIC:                            -77.23
# Df Residuals:                      34   BIC:                            -74.06
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0900      0.163      0.552      0.581      -0.230       0.410
# E/P           -1.6785      3.731     -0.450      0.653      -8.991       5.634
# ==============================================================================
# Omnibus:                        2.708   Durbin-Watson:                   2.877
# Prob(Omnibus):                  0.258   Jarque-Bera (JB):                1.864
# Skew:                          -0.552   Prob(JB):                        0.394
# Kurtosis:                       3.158   Cond. No.                         363.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                   0.01903
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.891
# Time:                        21:28:42   Log-Likelihood:                 40.760
# No. Observations:                  36   AIC:                            -77.52
# Df Residuals:                      34   BIC:                            -74.35
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0374      0.160      0.234      0.815      -0.276       0.350
# E/P           -0.5004      3.627     -0.138      0.890      -7.610       6.609
# ==============================================================================
# Omnibus:                        2.941   Durbin-Watson:                   2.892
# Prob(Omnibus):                  0.230   Jarque-Bera (JB):                1.993
# Skew:                          -0.565   Prob(JB):                        0.369
# Kurtosis:                       3.228   Cond. No.                         370.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                    0.1505
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):              0.700
# Time:                        21:28:43   Log-Likelihood:                 40.840
# No. Observations:                  36   AIC:                            -77.68
# Df Residuals:                      34   BIC:                            -74.51
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0826      0.161      0.512      0.609      -0.234       0.399
# E/P           -1.4202      3.661     -0.388      0.698      -8.596       5.755
# ==============================================================================
# Omnibus:                        4.045   Durbin-Watson:                   2.711
# Prob(Omnibus):                  0.132   Jarque-Bera (JB):                2.878
# Skew:                          -0.670   Prob(JB):                        0.237
# Kurtosis:                       3.354   Cond. No.                         377.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)

# %%
pd_est_model.mean()
# Out:
# error_sq    0.008
# dtype: float64

# %%
pd_est_model2.mean()
# Out:
# error_sq    0.008
# dtype: float64

# %%
from scipy.stats import ttest_ind
statistic, pvalue = ttest_ind(a=pd_est_model['error_sq'],b=pd_est_model2['error_sq'])
statistic
# Out:
# -0.698491656684882

# %%
pd_est_model['error_sq'].sum()
# Out:
# 4.870570012070047

# %%
pd_est_model2['error_sq'].sum()
# Out:
# 5.265146004792021

# %% [markdown]
# Actually it is not right that adding an extra regressor will increase the forecast accuracy. The first model is better when we assume that the best prediction is the average return during the past particular period.

# %%
#2
df_annual = df[::12].reset_index()
del df_annual['index']

# %%
df_annual.head()
# Out:
#       Date      P      E   CAPE    E/P
# 0  1963,01 65.060  3.683 19.259  0.057
# 1  1964,01 76.450  4.073 21.627  0.053
# 2  1965,01 86.120  4.593 23.269  0.053
# 3  1966,01 93.320  5.240 24.058  0.056
# 4  1967,01 84.450  5.517 20.432  0.065

# %%
df_c_annual = df_c[['Date','Adj Close']].shift(-1)[::12]

# %%
df_c_annual['return'] = df_c_annual['Adj Close'].diff(1)/df_c_annual['Adj Close'].shift(1)

# %%
df_c_annual = df_c_annual[1:].reset_index()
del df_c_annual['index']

# %%
df_c_annual.head()
# Out:
#          Date  Adj Close  return
# 0  1964-01-01      0.197   0.399
# 1  1965-01-01      0.313   0.588
# 2  1966-01-01      0.389   0.241
# 3  1967-01-01      0.325  -0.164
# 4  1968-01-01      0.331   0.018

# %%
# first model
pd_est_model_2=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,37):
    model = OLS(df_c_annual.iloc[0+i:20+i,2], sm.add_constant(df_annual.iloc[0+i:20+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_c_annual.iloc[20+i,2])**2
    pd_est_model_2=pd_est_model_2.append({'date':df_c_annual.iloc[20+i,0],'error_sq':oos},ignore_index = True)

# %%
# second model
pd_est_model2_2=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,37):
    model = OLS(df_c_annual.iloc[0+i:20+i,2], sm.add_constant(df_annual.iloc[0+i:20+i,4]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df_annual.iloc[20+i,4] - df_c_annual.iloc[20+i,2])**2
    pd_est_model2_2=pd_est_model2_2.append({'date':df_c_annual.iloc[20+i,0],'error_sq':oos},ignore_index = True)

# %%
pd_est_model_2['error_sq'].sum()
# Out:
# 4.824037823561425

# %%
pd_est_model2_2['error_sq'].sum()
# Out:
# 4.8042612841011945

# %% [markdown]
# The result is a little bit better. I mean the sum of squares is less in the second model but not essentially. They both are still practicularly equal. If I decrease the number of rollings the result will be different, meaning the first model is better according to the sum of squares, but there is still not much difference between these two models. The results are practically the same as in the first trial. It means that there are no needs to add an additional regressor because the regressor 'e/p' does not have any power to predict the future returns whatever the period is. In addition, stock returns are really hard to predict.

# %%
#3
df_sp=pd.read_csv('df_sp.csv',sep = ";")

# %%
df_sp['E/P']=df_sp['E']/df_sp['P']
df_sp=df_sp[::12]

# %%
df_sp['return']= df_sp['P'].diff(1)/df_sp['P'].shift(1)
df_sp_r = df_sp[['Date','return']].shift(-1).reset_index()
del df_sp_r['index']
df_sp_r.head()
# Out:
#       Date  return
# 0  1882,01  -0.044
# 1  1883,01  -0.019
# 2  1884,01  -0.108
# 3  1885,01  -0.181
# 4  1886,01   0.226

# %%
df_sp=df_sp.reset_index()
del df_sp['index']

# %%
df_sp.head()
# Out:
#       Date      P      D      E   CAPE    E/P  return
# 0  1881,01  6.190  0.265  0.486 18.474  0.078     nan
# 1  1882,01  5.920  0.320  0.439 15.679  0.074  -0.044
# 2  1883,01  5.810  0.321  0.427 15.270  0.074  -0.019
# 3  1884,01  5.180  0.328  0.393 14.433  0.076  -0.108
# 4  1885,01  4.240  0.304  0.307 13.130  0.072  -0.181

# %%
#10 years

#first model
pd_est_model_3_10=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,128):
    model = OLS(df_sp_r.iloc[0+i:10+i,1], sm.add_constant(df_sp.iloc[0+i:10+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_sp_r.iloc[10+i,1])**2
    pd_est_model_3_10=pd_est_model_3_10.append({'date':df_sp_r.iloc[10+i,0],'error_sq':oos},ignore_index = True)

# %%
# second model
pd_est_model2_3_10=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,128):
    model = OLS(df_sp_r.iloc[0+i:10+i,1], sm.add_constant(df_sp.iloc[0+i:10+i,5]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df_sp.iloc[10+i,5] - df_sp_r.iloc[10+i,1])**2
    pd_est_model2_3_10=pd_est_model2_3_10.append({'date':df_sp_r.iloc[10+i,0],'error_sq':oos},ignore_index = True)

# %%
pd_est_model_3_10['error_sq'].sum()
# Out:
# 4.42049854291729

# %%
pd_est_model2_3_10['error_sq'].sum()
# Out:
# 5.802794941652946

# %%
#20 years

#first model 
pd_est_model_3_20=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,118):
    model = OLS(df_sp_r.iloc[0+i:20+i,1], sm.add_constant(df_sp.iloc[0+i:20+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_sp_r.iloc[20+i,1])**2
    pd_est_model_3_20=pd_est_model_3_20.append({'date':df_sp_r.iloc[20+i,0],'error_sq':oos},ignore_index = True)

# %%
# second model
pd_est_model2_3_20=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,118):
    model = OLS(df_sp_r.iloc[0+i:20+i,1], sm.add_constant(df_sp.iloc[0+i:20+i,5]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df_sp.iloc[20+i,5] - df_sp_r.iloc[20+i,1])**2
    pd_est_model2_3_20=pd_est_model2_3_20.append({'date':df_sp_r.iloc[20+i,0],'error_sq':oos},ignore_index = True)

# %%
pd_est_model_3_20['error_sq'].sum()
# Out:
# 4.132557567404263

# %%
pd_est_model2_3_20['error_sq'].sum()
# Out:
# 4.4702309813638115

# %%
#30 years 

#first model
pd_est_model_3_30=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,108):
    model = OLS(df_sp_r.iloc[0+i:30+i,1], sm.add_constant(df_sp.iloc[0+i:30+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_sp_r.iloc[30+i,1])**2
    pd_est_model_3_30=pd_est_model_3_30.append({'date':df_sp_r.iloc[30+i,0],'error_sq':oos},ignore_index = True)

# %%
#second model
pd_est_model2_3_30=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,108):
    model = OLS(df_sp_r.iloc[0+i:30+i,1], sm.add_constant(df_sp.iloc[0+i:30+i,5]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df_sp.iloc[30+i,5] - df_sp_r.iloc[30+i,1])**2
    pd_est_model2_3_30=pd_est_model2_3_30.append({'date':df_sp_r.iloc[30+i,0],'error_sq':oos},ignore_index = True)

# %%
pd_est_model_3_30['error_sq'].sum()
# Out:
# 3.652791903163243

# %%
pd_est_model2_3_30['error_sq'].sum()
# Out:
# 3.8160821867940617

# %% [markdown]
# In each case the first model is better. There is no much difference with the second trial because there we predict the future return of the stock but here we predict the return of the index. The return of the index is also hard to forecast, that is why the first model shows better predictions as in the second trial (2) because the regrossor 'e/p' does not explain altering in the return. The best prediction is still average past returns. When we use 10 years in sample the result in the second model for forecasting is not so good because we have a few returns and the regression does not work perfectly for predicting the result which is out of sample.

# %%
#4
#10 years

#first model
pd_est_model_4_10=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,128):
    model = OLS(df_sp_r.iloc[0+i:10+i,1], sm.add_constant(df_sp.iloc[0+i:10+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_sp_r.iloc[10+i,1])**2
    pd_est_model_4_10=pd_est_model_4_10.append({'date':df_sp_r.iloc[10+i,0],'error_sq':oos},ignore_index = True)

# %%
# second model
pd_est_model2_4_10=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,128):
    model = OLS(df_sp_r.iloc[0+i:10+i,1], sm.add_constant(df_sp.iloc[0+i:10+i,4]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df_sp.iloc[10+i,4] - df_sp_r.iloc[10+i,1])**2
    pd_est_model2_4_10=pd_est_model2_4_10.append({'date':df_sp_r.iloc[10+i,0],'error_sq':oos},ignore_index = True)

# %%
pd_est_model_4_10['error_sq'].sum()
# Out:
# 4.42049854291729

# %%
pd_est_model2_4_10['error_sq'].sum()
# Out:
# 5.376231554054691

# %%
#20 years

#first model 
pd_est_model_4_20=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,118):
    model = OLS(df_sp_r.iloc[0+i:20+i,1], sm.add_constant(df_sp.iloc[0+i:20+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_sp_r.iloc[20+i,1])**2
    pd_est_model_4_20=pd_est_model_4_20.append({'date':df_sp_r.iloc[20+i,0],'error_sq':oos},ignore_index = True)

# %%
# second model
pd_est_model2_4_20=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,118):
    model = OLS(df_sp_r.iloc[0+i:20+i,1], sm.add_constant(df_sp.iloc[0+i:20+i,4]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df_sp.iloc[20+i,4] - df_sp_r.iloc[20+i,1])**2
    pd_est_model2_4_20=pd_est_model2_4_20.append({'date':df_sp_r.iloc[20+i,0],'error_sq':oos},ignore_index = True)

# %%
pd_est_model_4_20['error_sq'].sum()
# Out:
# 4.132557567404263

# %%
pd_est_model2_4_20['error_sq'].sum()
# Out:
# 4.23587269626587

# %%
#30 years 

#first model
pd_est_model_4_30=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,108):
    model = OLS(df_sp_r.iloc[0+i:30+i,1], sm.add_constant(df_sp.iloc[0+i:30+i,4])['const'])
    result = model.fit(cov_type='HC0')
    oos=(result.params[0] - df_sp_r.iloc[30+i,1])**2
    pd_est_model_4_30=pd_est_model_4_30.append({'date':df_sp_r.iloc[30+i,0],'error_sq':oos},ignore_index = True)

# %%
#second model
pd_est_model2_4_30=pd.DataFrame(columns=['date','error_sq'])
for i in range(0,108):
    model = OLS(df_sp_r.iloc[0+i:30+i,1], sm.add_constant(df_sp.iloc[0+i:30+i,4]))
    result = model.fit(cov_type='HC0')
    oos=(result.params[0]+result.params[1]*df_sp.iloc[30+i,4] - df_sp_r.iloc[30+i,1])**2
    pd_est_model2_4_30=pd_est_model2_4_30.append({'date':df_sp_r.iloc[30+i,0],'error_sq':oos},ignore_index = True)

# %%
pd_est_model_4_30['error_sq'].sum()
# Out:
# 3.652791903163243

# %%
pd_est_model2_4_30['error_sq'].sum()
# Out:
# 3.6897753096203325

# %% [markdown]
# There is no much difference. The first model is still better for predicting. CAPE is also not good for predicting the return which is out of sample whatever the period is for testing the model. CAPE is similar to E/P but not so much for computing the ratio we have to adjust for inflation and compute the average eps during the past several months/years. In other words, in these ratios we use practically the same things eps and the price but using these numbers they do not explain altering in the future returns as the model shows to us. It is still better to use the past average returns than to add CAPE or E/P to the model.

# %% [markdown]
# #5
# We may use t test for proving statistical difference between the models, especially we can compute the means of two models and than assume that there is no difference between them. It means that the means shoud be equal. H0 hypothesis is that the means are equal, the alternative hypothesis is that they are not.

# %%
#5_1
statistic, pvalue = ttest_ind(a=pd_est_model['error_sq'],b=pd_est_model2['error_sq'])
statistic
# Out:
# -0.698491656684882

# %%
#5_2
statistic, pvalue = ttest_ind(a=pd_est_model_2['error_sq'],b=pd_est_model2_2['error_sq'])
statistic
# Out:
# 0.0127750377941473

# %%
#5_3 10 years
statistic, pvalue = ttest_ind(a=pd_est_model_3_10['error_sq'],b=pd_est_model2_3_10['error_sq'])
statistic
# Out:
# -1.2886791474075663

# %%
#5_3 20 years
statistic, pvalue = ttest_ind(a=pd_est_model_3_20['error_sq'],b=pd_est_model2_3_20['error_sq'])
statistic
# Out:
# -0.42254502139420164

# %%
#5_3 30 years
statistic, pvalue = ttest_ind(a=pd_est_model_3_30['error_sq'],b=pd_est_model2_3_30['error_sq'])
statistic
# Out:
# -0.21691208793317573

# %%
#5_4 10 years 
statistic, pvalue = ttest_ind(a=pd_est_model_4_10['error_sq'],b=pd_est_model2_4_10['error_sq'])
statistic
# Out:
# -0.9552731897105783

# %%
#5_4 20 years
statistic, pvalue = ttest_ind(a=pd_est_model_4_20['error_sq'],b=pd_est_model2_4_20['error_sq'])
statistic
# Out:
# -0.13472775691171784

# %%
#5_4 30 years
statistic, pvalue = ttest_ind(a=pd_est_model_4_30['error_sq'],b=pd_est_model2_4_30['error_sq'])
statistic
# Out:
# -0.05147973207322748

# %% [markdown]
# We may see that in each case h0 hypothesis is not rejected, meaning that statistically both models in each case have equal means. Therefore, they do not differ.

# %%
#5 (3) and (4) 10 years 
statistic, pvalue = ttest_ind(a=pd_est_model2_3_10['error_sq'],b=pd_est_model2_4_10['error_sq'])
statistic
# Out:
# 0.349092927510412

# %%
#5 (3) and (4) 20 years 
statistic, pvalue = ttest_ind(a=pd_est_model2_3_20['error_sq'],b=pd_est_model2_4_20['error_sq'])
statistic
# Out:
# 0.2914787578239047

# %%
#5 (3) and (4) 30 years 
statistic, pvalue = ttest_ind(a=pd_est_model2_3_30['error_sq'],b=pd_est_model2_4_30['error_sq'])
statistic
# Out:
# 0.17325891738526447

# %% [markdown]
# I compare the second model with the different regressors. The means of both models do not statistically differ because H0 hypothesis is not rejected.
